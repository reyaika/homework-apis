# %%
# June 10, 2025
# Homework 5 Part 2

# %%
# PART TWO:

# The questions below are the same as we used for the last homework with WeatherAPI, but this time try to complete them with either Open MeteoLinks to an external site., or TomorrowLinks to an external site., two alternate APIs for weather forecasts. This assignment is to help you understand how different individual APIs might be, even if they're about the same topic! Note that:

# Depending on the service you pick, you might not be able to answer all of the questions
# You might have figure out workarounds to get answers
# Compared to Weather API, these APIs might be either more or less difficult

# I'll be using Tomorrow API

# %%
# What is the URL to the documentation?
# https://docs.tomorrow.io/reference/welcome

# %%
# Make a request for the current weather where you are born, or somewhere you've lived.

import requests
import json

from dotenv import load_dotenv
import os

load_dotenv()

api_key_tomorrow = os.getenv("api_key_tomorrow")

location = "manila"

url = f"https://api.tomorrow.io/v4/weather/realtime?location={location}&apikey={api_key_tomorrow}"

response = requests.get(url)
weather = response.json()

pretty_json = json.dumps(weather, indent=4)
print(pretty_json)
# Out:
# {
#     "data": {
#         "time": "2025-06-10T17:47:00Z",
#         "values": {
#             "cloudBase": 1.1,
#             "cloudCeiling": 12.3,
#             "cloudCover": 100,
#             "dewPoint": 25.3,
#             "freezingRainIntensity": 0,
#             "humidity": 89,
#             "precipitationProbability": 50,
#             "pressureSeaLevel": 1004.9,
#             "pressureSurfaceLevel": 1003.19,
#             "rainIntensity": 4.48,
#             "sleetIntensity": 0,
#             "snowIntensity": 0,
#             "temperature": 27.3,
#             "temperatureApparent": 31.4,
#             "visibility": 16,
#             "weatherCode": 4001,
#             "windDirection": 217,
#             "windGust": 6.4,
#             "windSpeed": 2.7
#         }
#     },
#     "location": {
#         "lat": 14.590449333190918,
#         "lon": 120.98036193847656,
#         "name": "Manila, Capital District, Metro Manila, Pilipinas",
#         "type": "administrative"
#     }
# }

# %%
# Print out the country this location is in.

print(weather['location']['name'])
# Out:
# Manila, Capital District, Metro Manila, Pilipinas

# %%
# Print out the difference between the current temperature and how warm it feels. Use "It feels ___ degrees colder" or "It feels ___ degrees warmer," not negative numbers.

actual_temp = weather['data']['values']['temperature']
feels_like = weather['data']['values']['temperatureApparent']
difference = round((abs(feels_like - actual_temp)))

if feels_like > actual_temp:
    print(f"It feels {difference} degrees warmer.")
elif feels_like < actual_temp:
    print(f"It feels {difference} degrees colder.")
else:
    print("It feels the same as the actual temperature.")
# Out:
# It feels 4 degrees warmer.

# %%
# What's the current temperature at Heathrow International Airport? Use the airport's IATA code to search.
# It misinterprets LHR as Lahore. 
# Also returns "...try a different term" when I put Heathrow International Airport.

location_lhr = "Heathrow Airport"
url_lhr = f"https://api.tomorrow.io/v4/weather/realtime?location={location_lhr}&apikey={api_key_tomorrow}"

response = requests.get(url_lhr)
weather_lhr = response.json()
pretty_json = json.dumps(weather_lhr, indent=4)
print(pretty_json)
# Out:
# {
#     "data": {
#         "time": "2025-06-10T17:47:00Z",
#         "values": {
#             "cloudBase": 1.5,
#             "cloudCeiling": 12.3,
#             "cloudCover": 87,
#             "dewPoint": 14,
#             "freezingRainIntensity": 0,
#             "humidity": 58,
#             "precipitationProbability": 0,
#             "pressureSeaLevel": 1017.98,
#             "pressureSurfaceLevel": 1016.68,
#             "rainIntensity": 0,
#             "sleetIntensity": 0,
#             "snowIntensity": 0,
#             "temperature": 22.7,
#             "temperatureApparent": 22.7,
#             "visibility": 16,
#             "weatherCode": 1001,
#             "windDirection": 330,
#             "windGust": 4.2,
#             "windSpeed": 1.2
#         }
#     },
#     "location": {
#         "lat": 51.46773910522461,
#         "lon": -0.45878008008003235,
#         "name": "London Heathrow Airport, Northern Perimeter Road, London Borough of Hillingdon, London, Greater London, England, TW6 2RN, United Kingdom",
#         "type": "aerodrome"
#     }
# }

# %%
# If I want to ••really•• use LHR then...

LHR = "Heathrow Airport"
url_lhr_iata = f"https://api.tomorrow.io/v4/weather/realtime?location={LHR}&apikey={api_key_tomorrow}"

response = requests.get(url_lhr_iata)
weather_lhr_iata = response.json()
pretty_json = json.dumps(weather_lhr_iata, indent=4)
print(pretty_json)
# Out:
# {
#     "data": {
#         "time": "2025-06-10T17:43:00Z",
#         "values": {
#             "cloudBase": 1.7,
#             "cloudCeiling": 12.3,
#             "cloudCover": 90,
#             "dewPoint": 13,
#             "freezingRainIntensity": 0,
#             "humidity": 52,
#             "precipitationProbability": 0,
#             "pressureSeaLevel": 1017.98,
#             "pressureSurfaceLevel": 1014.89,
#             "rainIntensity": 0,
#             "sleetIntensity": 0,
#             "snowIntensity": 0,
#             "temperature": 23.2,
#             "temperatureApparent": 23.2,
#             "visibility": 16,
#             "weatherCode": 1001,
#             "windDirection": 336,
#             "windGust": 5.7,
#             "windSpeed": 3.6
#         }
#     },
#     "location": {
#         "lat": 51.46773910522461,
#         "lon": -0.45878008008003235,
#         "name": "London Heathrow Airport, Northern Perimeter Road, London Borough of Hillingdon, London, Greater London, England, TW6 2RN, United Kingdom",
#         "type": "aerodrome"
#     }
# }

# %%
# Current temperature at LHR

print(f"It's currently {weather_lhr['data']['values']['temperature']} degrees Celsius at {weather_lhr['location']['name']}.")
# Out:
# It's currently 22.7 degrees Celsius at London Heathrow Airport, Northern Perimeter Road, London Borough of Hillingdon, London, Greater London, England, TW6 2RN, United Kingdom.

# %%
# What URL would I use to request a 3-day forecast at Heathrow?
# The default is 5 days so I will have to slice the list later...

location_lhr = "Heathrow Airport"
url_forecast = f"https://api.tomorrow.io/v4/weather/forecast?location={location_lhr}&timesteps=1d&apikey={api_key_tomorrow}"

response = requests.get(url_forecast)
weather_forecast = response.json()
pretty_json = json.dumps(weather_forecast, indent=4)
print(pretty_json)
# Out:
# {
#     "timelines": {
#         "daily": [
#             {
#                 "time": "2025-06-10T05:00:00Z",
#                 "values": {
#                     "cloudBaseAvg": 2.1,
#                     "cloudBaseMax": 11.7,
#                     "cloudBaseMin": 0,
#                     "cloudCeilingAvg": 4.5,
#                     "cloudCeilingMax": 12.5,
#                     "cloudCeilingMin": 0,
#                     "cloudCoverAvg": 77,
#                     "cloudCoverMax": 100,
#                     "cloudCoverMin": 0,
#                     "dewPointAvg": 11.7,
#                     "dewPointMax": 15.1,
#                     "dewPointMin": 9.9,
#                     "evapotranspirationAvg": 0.144,
#                     "evapotranspirationMax": 0.245,
#                     "evapotranspirationMin": 0.036,
#                     "evapotranspirationSum": 3.459,
#                     "freezingRainIntensityAvg": 0,
#                     "freezingRainIntensityMax": 0,
#                     "freezingRainIntensityMin": 0,
#                     "humidityAvg": 70,
#                     "humidityMax": 86,
#                     "humidityMin": 52,
#                     "iceAccumulationAvg": 0,
#                     "iceAccumulationLweAvg": 0,
#                     "iceAccumulationLweMax": 0,
#                     "iceAccumulationLweMin": 0,
#                     "iceAccumulationLweSum": 0,
#                     "iceAccumulationMax": 0,
#                     "iceAccumulationMin": 0,
#                     "iceAccumulationSum": 0,
#                     "moonriseTime": "2025-06-10T20:14:41Z",
#                     "moonsetTime": "2025-06-10T02:28:29Z",
#                     "precipitationProbabilityAvg": 0,
#                     "precipitationProbabilityMax": 0,
#                     "precipitationProbabilityMin": 0,
#                     "pressureSeaLevelAvg": 1017.78,
#                     "pressureSeaLevelMax": 1020.51,
#                     "pressureSeaLevelMin": 1015.1,
#                     "pressureSurfaceLevelAvg": 1015.2,
#                     "pressureSurfaceLevelMax": 1017.91,
#                     "pressureSurfaceLevelMin": 1011.53,
#                     "rainAccumulationAvg": 0,
#                     "rainAccumulationMax": 0.02,
#                     "rainAccumulationMin": 0,
#                     "rainAccumulationSum": 0.02,
#                     "rainIntensityAvg": 0,
#                     "rainIntensityMax": 0,
#                     "rainIntensityMin": 0,
#                     "sleetAccumulationAvg": 0,
#                     "sleetAccumulationLweAvg": 0,
#                     "sleetAccumulationLweMax": 0,
#                     "sleetAccumulationLweMin": 0,
#                     "sleetAccumulationLweSum": 0,
#                     "sleetAccumulationMax": 0,
#                     "sleetAccumulationMin": 0,
#                     "sleetIntensityAvg": 0,
#                     "sleetIntensityMax": 0,
#                     "sleetIntensityMin": 0,
#                     "snowAccumulationAvg": 0,
#                     "snowAccumulationLweAvg": 0,
#                     "snowAccumulationLweMax": 0,
#                     "snowAccumulationLweMin": 0,
#                     "snowAccumulationLweSum": 0,
#                     "snowAccumulationMax": 0,
#                     "snowAccumulationMin": 0,
#                     "snowAccumulationSum": 0,
#                     "snowIntensityAvg": 0,
#                     "snowIntensityMax": 0,
#                     "snowIntensityMin": 0,
#                     "sunriseTime": "2025-06-10T04:08:00Z",
#                     "sunsetTime": "2025-06-10T19:54:00Z",
#                     "temperatureApparentAvg": 17.4,
#                     "temperatureApparentMax": 23.4,
#                     "temperatureApparentMin": 12.1,
#                     "temperatureAvg": 17.4,
#                     "temperatureMax": 23.4,
#                     "temperatureMin": 12.1,
#                     "uvHealthConcernAvg": 0,
#                     "uvHealthConcernMax": 1,
#                     "uvHealthConcernMin": 0,
#                     "uvIndexAvg": 1,
#                     "uvIndexMax": 4,
#                     "uvIndexMin": 0,
#                     "visibilityAvg": 16,
#                     "visibilityMax": 16,
#                     "visibilityMin": 16,
#                     "weatherCodeMax": 1001,
#                     "weatherCodeMin": 1001,
#                     "windDirectionAvg": 189,
#                     "windGustAvg": 5.9,
#                     "windGustMax": 11.4,
#                     "windGustMin": 3,
#                     "windSpeedAvg": 2.7,
#                     "windSpeedMax": 5.2,
#                     "windSpeedMin": 1.1
#                 }
#             },
#             {
#                 "time": "2025-06-11T05:00:00Z",
#                 "values": {
#                     "cloudBaseAvg": 3.8,
#                     "cloudBaseMax": 11.4,
#                     "cloudBaseMin": 0,
#                     "cloudCeilingAvg": 3.8,
#                     "cloudCeilingMax": 11.9,
#                     "cloudCeilingMin": 0,
#                     "cloudCoverAvg": 70,
#                     "cloudCoverMax": 100,
#                     "cloudCoverMin": 12,
#                     "dewPointAvg": 11.7,
#                     "dewPointMax": 14,
#                     "dewPointMin": 9.4,
#                     "evapotranspirationAvg": 0.148,
#                     "evapotranspirationMax": 0.226,
#                     "evapotranspirationMin": 0.071,
#                     "evapotranspirationSum": 3.545,
#                     "freezingRainIntensityAvg": 0,
#                     "freezingRainIntensityMax": 0,
#                     "freezingRainIntensityMin": 0,
#                     "humidityAvg": 67,
#                     "humidityMax": 84,
#                     "humidityMin": 49,
#                     "iceAccumulationAvg": 0,
#                     "iceAccumulationLweAvg": 0,
#                     "iceAccumulationLweMax": 0,
#                     "iceAccumulationLweMin": 0,
#                     "iceAccumulationLweSum": 0,
#                     "iceAccumulationMax": 0,
#                     "iceAccumulationMin": 0,
#                     "iceAccumulationSum": 0,
#                     "moonriseTime": "2025-06-11T21:15:29Z",
#                     "moonsetTime": "2025-06-11T03:04:20Z",
#                     "precipitationProbabilityAvg": 0.6,
#                     "precipitationProbabilityMax": 5,
#                     "precipitationProbabilityMin": 0,
#                     "pressureSeaLevelAvg": 1017.67,
#                     "pressureSeaLevelMax": 1020.64,
#                     "pressureSeaLevelMin": 1013.41,
#                     "pressureSurfaceLevelAvg": 1015.14,
#                     "pressureSurfaceLevelMax": 1018.06,
#                     "pressureSurfaceLevelMin": 1010.92,
#                     "rainAccumulationAvg": 0,
#                     "rainAccumulationMax": 0,
#                     "rainAccumulationMin": 0,
#                     "rainAccumulationSum": 0,
#                     "rainIntensityAvg": 0.01,
#                     "rainIntensityMax": 0.06,
#                     "rainIntensityMin": 0,
#                     "sleetIntensityAvg": 0,
#                     "sleetIntensityMax": 0,
#                     "sleetIntensityMin": 0,
#                     "snowAccumulationAvg": 0,
#                     "snowAccumulationLweAvg": 0,
#                     "snowAccumulationLweMax": 0,
#                     "snowAccumulationLweMin": 0,
#                     "snowAccumulationLweSum": 0,
#                     "snowAccumulationMax": 0,
#                     "snowAccumulationMin": 0,
#                     "snowAccumulationSum": 0,
#                     "snowIntensityAvg": 0,
#                     "snowIntensityMax": 0,
#                     "snowIntensityMin": 0,
#                     "sunriseTime": "2025-06-11T04:08:00Z",
#                     "sunsetTime": "2025-06-11T19:54:00Z",
#                     "temperatureApparentAvg": 18.2,
#                     "temperatureApparentMax": 23.1,
#                     "temperatureApparentMin": 12.7,
#                     "temperatureAvg": 18.2,
#                     "temperatureMax": 23.1,
#                     "temperatureMin": 12.7,
#                     "uvHealthConcernAvg": 0,
#                     "uvHealthConcernMax": 1,
#                     "uvHealthConcernMin": 0,
#                     "uvIndexAvg": 1,
#                     "uvIndexMax": 5,
#                     "uvIndexMin": 0,
#                     "visibilityAvg": 16,
#                     "visibilityMax": 16,
#                     "visibilityMin": 16,
#                     "weatherCodeMax": 1001,
#                     "weatherCodeMin": 1001,
#                     "windDirectionAvg": 107,
#                     "windGustAvg": 8.2,
#                     "windGustMax": 10.7,
#                     "windGustMin": 4.3,
#                     "windSpeedAvg": 3.7,
#                     "windSpeedMax": 4.6,
#                     "windSpeedMin": 2.2
#                 }
#             },
#             {
#                 "time": "2025-06-12T05:00:00Z",
#                 "values": {
#                     "cloudBaseAvg": 2.1,
#                     "cloudBaseMax": 9.4,
#                     "cloudBaseMin": 0,
#                     "cloudCeilingAvg": 3,
#                     "cloudCeilingMax": 11.3,
#                     "cloudCeilingMin": 0,
#                     "cloudCoverAvg": 58,
#                     "cloudCoverMax": 100,
#                     "cloudCoverMin": 0,
#                     "dewPointAvg": 13.8,
#                     "dewPointMax": 16.4,
#                     "dewPointMin": 11.2,
#                     "evapotranspirationAvg": 0.137,
#                     "evapotranspirationMax": 0.204,
#                     "evapotranspirationMin": 0.085,
#                     "evapotranspirationSum": 3.296,
#                     "freezingRainIntensityAvg": 0,
#                     "freezingRainIntensityMax": 0,
#                     "freezingRainIntensityMin": 0,
#                     "humidityAvg": 72,
#                     "humidityMax": 91,
#                     "humidityMin": 57,
#                     "iceAccumulationAvg": 0,
#                     "iceAccumulationLweAvg": 0,
#                     "iceAccumulationLweMax": 0,
#                     "iceAccumulationLweMin": 0,
#                     "iceAccumulationLweSum": 0,
#                     "iceAccumulationMax": 0,
#                     "iceAccumulationMin": 0,
#                     "iceAccumulationSum": 0,
#                     "moonriseTime": "2025-06-12T22:03:46Z",
#                     "moonsetTime": "2025-06-12T03:52:44Z",
#                     "precipitationProbabilityAvg": 0.8,
#                     "precipitationProbabilityMax": 20,
#                     "precipitationProbabilityMin": 0,
#                     "pressureSeaLevelAvg": 1013.25,
#                     "pressureSeaLevelMax": 1016.51,
#                     "pressureSeaLevelMin": 1011.15,
#                     "pressureSurfaceLevelAvg": 1010.76,
#                     "pressureSurfaceLevelMax": 1014.01,
#                     "pressureSurfaceLevelMin": 1008.65,
#                     "rainAccumulationAvg": 0.02,
#                     "rainAccumulationMax": 0.37,
#                     "rainAccumulationMin": 0,
#                     "rainAccumulationSum": 0.37,
#                     "rainIntensityAvg": 0.01,
#                     "rainIntensityMax": 0.27,
#                     "rainIntensityMin": 0,
#                     "sleetIntensityAvg": 0,
#                     "sleetIntensityMax": 0,
#                     "sleetIntensityMin": 0,
#                     "snowAccumulationAvg": 0,
#                     "snowAccumulationLweAvg": 0,
#                     "snowAccumulationLweMax": 0,
#                     "snowAccumulationLweMin": 0,
#                     "snowAccumulationLweSum": 0,
#                     "snowAccumulationMax": 0,
#                     "snowAccumulationMin": 0,
#                     "snowAccumulationSum": 0,
#                     "snowIntensityAvg": 0,
#                     "snowIntensityMax": 0,
#                     "snowIntensityMin": 0,
#                     "sunriseTime": "2025-06-12T04:08:00Z",
#                     "sunsetTime": "2025-06-12T19:55:00Z",
#                     "temperatureApparentAvg": 19.2,
#                     "temperatureApparentMax": 24.1,
#                     "temperatureApparentMin": 14.7,
#                     "temperatureAvg": 19.2,
#                     "temperatureMax": 24.1,
#                     "temperatureMin": 14.7,
#                     "uvHealthConcernAvg": 0,
#                     "uvHealthConcernMax": 2,
#                     "uvHealthConcernMin": 0,
#                     "uvIndexAvg": 2,
#                     "uvIndexMax": 6,
#                     "uvIndexMin": 0,
#                     "visibilityAvg": 15.63,
#                     "visibilityMax": 16,
#                     "visibilityMin": 7.14,
#                     "weatherCodeMax": 1001,
#                     "weatherCodeMin": 1001,
#                     "windDirectionAvg": 158,
#                     "windGustAvg": 6.4,
#                     "windGustMax": 11.2,
#                     "windGustMin": 2.3,
#                     "windSpeedAvg": 3,
#                     "windSpeedMax": 4.8,
#                     "windSpeedMin": 1.3
#                 }
#             },
#             {
#                 "time": "2025-06-13T05:00:00Z",
#                 "values": {
#                     "cloudBaseAvg": 1.9,
#                     "cloudBaseMax": 9,
#                     "cloudBaseMin": 0,
#                     "cloudCeilingAvg": 3.2,
#                     "cloudCeilingMax": 10.8,
#                     "cloudCeilingMin": 0,
#                     "cloudCoverAvg": 67,
#                     "cloudCoverMax": 100,
#                     "cloudCoverMin": 1,
#                     "dewPointAvg": 14.6,
#                     "dewPointMax": 17.5,
#                     "dewPointMin": 12.3,
#                     "evapotranspirationAvg": 0.138,
#                     "evapotranspirationMax": 0.217,
#                     "evapotranspirationMin": 0.087,
#                     "evapotranspirationSum": 3.323,
#                     "freezingRainIntensityAvg": 0,
#                     "freezingRainIntensityMax": 0,
#                     "freezingRainIntensityMin": 0,
#                     "humidityAvg": 69,
#                     "humidityMax": 96,
#                     "humidityMin": 42,
#                     "iceAccumulationAvg": 0,
#                     "iceAccumulationLweAvg": 0,
#                     "iceAccumulationLweMax": 0,
#                     "iceAccumulationLweMin": 0,
#                     "iceAccumulationLweSum": 0,
#                     "iceAccumulationMax": 0,
#                     "iceAccumulationMin": 0,
#                     "iceAccumulationSum": 0,
#                     "moonriseTime": "2025-06-13T22:40:42Z",
#                     "moonsetTime": "2025-06-13T04:56:58Z",
#                     "precipitationProbabilityAvg": 3.8,
#                     "precipitationProbabilityMax": 25,
#                     "precipitationProbabilityMin": 0,
#                     "pressureSeaLevelAvg": 1016.22,
#                     "pressureSeaLevelMax": 1017.72,
#                     "pressureSeaLevelMin": 1012.78,
#                     "pressureSurfaceLevelAvg": 1013.72,
#                     "pressureSurfaceLevelMax": 1015.24,
#                     "pressureSurfaceLevelMin": 1010.28,
#                     "rainAccumulationAvg": 0.09,
#                     "rainAccumulationMax": 1.6,
#                     "rainAccumulationMin": 0,
#                     "rainAccumulationSum": 2.15,
#                     "rainIntensityAvg": 0.05,
#                     "rainIntensityMax": 0.68,
#                     "rainIntensityMin": 0,
#                     "sleetIntensityAvg": 0,
#                     "sleetIntensityMax": 0,
#                     "sleetIntensityMin": 0,
#                     "snowAccumulationAvg": 0,
#                     "snowAccumulationLweAvg": 0,
#                     "snowAccumulationLweMax": 0,
#                     "snowAccumulationLweMin": 0,
#                     "snowAccumulationLweSum": 0,
#                     "snowAccumulationMax": 0,
#                     "snowAccumulationMin": 0,
#                     "snowAccumulationSum": 0,
#                     "snowIntensityAvg": 0,
#                     "snowIntensityMax": 0,
#                     "snowIntensityMin": 0,
#                     "sunriseTime": "2025-06-13T04:08:00Z",
#                     "sunsetTime": "2025-06-13T19:55:00Z",
#                     "temperatureApparentAvg": 21.1,
#                     "temperatureApparentMax": 26.7,
#                     "temperatureApparentMin": 15.5,
#                     "temperatureAvg": 21.1,
#                     "temperatureMax": 26.7,
#                     "temperatureMin": 15.5,
#                     "uvHealthConcernAvg": 0,
#                     "uvHealthConcernMax": 1,
#                     "uvHealthConcernMin": 0,
#                     "uvIndexAvg": 2,
#                     "uvIndexMax": 5,
#                     "uvIndexMin": 0,
#                     "visibilityAvg": 16,
#                     "visibilityMax": 16,
#                     "visibilityMin": 16,
#                     "weatherCodeMax": 1001,
#                     "weatherCodeMin": 1001,
#                     "windDirectionAvg": 178,
#                     "windGustAvg": 5,
#                     "windGustMax": 8.1,
#                     "windGustMin": 2.8,
#                     "windSpeedAvg": 2.1,
#                     "windSpeedMax": 3.4,
#                     "windSpeedMin": 1.3
#                 }
#             },
#             {
#                 "time": "2025-06-14T05:00:00Z",
#                 "values": {
#                     "cloudBaseAvg": 0.7,
#                     "cloudBaseMax": 1.4,
#                     "cloudBaseMin": 0,
#                     "cloudCeilingAvg": 1.1,
#                     "cloudCeilingMax": 8.6,
#                     "cloudCeilingMin": 0,
#                     "cloudCoverAvg": 29,
#                     "cloudCoverMax": 93,
#                     "cloudCoverMin": 0,
#                     "dewPointAvg": 12.6,
#                     "dewPointMax": 16.5,
#                     "dewPointMin": 10.4,
#                     "evapotranspirationAvg": 0.129,
#                     "evapotranspirationMax": 0.203,
#                     "evapotranspirationMin": 0.083,
#                     "evapotranspirationSum": 3.093,
#                     "freezingRainIntensityAvg": 0,
#                     "freezingRainIntensityMax": 0,
#                     "freezingRainIntensityMin": 0,
#                     "humidityAvg": 75,
#                     "humidityMax": 92,
#                     "humidityMin": 50,
#                     "iceAccumulationAvg": 0,
#                     "iceAccumulationLweAvg": 0,
#                     "iceAccumulationLweMax": 0,
#                     "iceAccumulationLweMin": 0,
#                     "iceAccumulationLweSum": 0,
#                     "iceAccumulationMax": 0,
#                     "iceAccumulationMin": 0,
#                     "iceAccumulationSum": 0,
#                     "moonriseTime": "2025-06-14T23:06:07Z",
#                     "moonsetTime": "2025-06-14T06:11:56Z",
#                     "precipitationProbabilityAvg": 0.6,
#                     "precipitationProbabilityMax": 5,
#                     "precipitationProbabilityMin": 0,
#                     "pressureSeaLevelAvg": 1018.25,
#                     "pressureSeaLevelMax": 1021.41,
#                     "pressureSeaLevelMin": 1014.26,
#                     "pressureSurfaceLevelAvg": 1015.72,
#                     "pressureSurfaceLevelMax": 1018.88,
#                     "pressureSurfaceLevelMin": 1011.79,
#                     "rainAccumulationAvg": 0,
#                     "rainAccumulationMax": 0,
#                     "rainAccumulationMin": 0,
#                     "rainAccumulationSum": 0,
#                     "rainIntensityAvg": 0,
#                     "rainIntensityMax": 0.02,
#                     "rainIntensityMin": 0,
#                     "sleetIntensityAvg": 0,
#                     "sleetIntensityMax": 0,
#                     "sleetIntensityMin": 0,
#                     "snowAccumulationAvg": 0,
#                     "snowAccumulationLweAvg": 0,
#                     "snowAccumulationLweMax": 0,
#                     "snowAccumulationLweMin": 0,
#                     "snowAccumulationLweSum": 0,
#                     "snowAccumulationMax": 0,
#                     "snowAccumulationMin": 0,
#                     "snowAccumulationSum": 0,
#                     "snowIntensityAvg": 0,
#                     "snowIntensityMax": 0,
#                     "snowIntensityMin": 0,
#                     "sunriseTime": "2025-06-14T04:08:00Z",
#                     "sunsetTime": "2025-06-14T19:56:00Z",
#                     "temperatureApparentAvg": 17.5,
#                     "temperatureApparentMax": 21.3,
#                     "temperatureApparentMin": 12.6,
#                     "temperatureAvg": 17.5,
#                     "temperatureMax": 21.3,
#                     "temperatureMin": 12.6,
#                     "uvHealthConcernAvg": 1,
#                     "uvHealthConcernMax": 1,
#                     "uvHealthConcernMin": 0,
#                     "uvIndexAvg": 2,
#                     "uvIndexMax": 3,
#                     "uvIndexMin": 0,
#                     "visibilityAvg": 16,
#                     "visibilityMax": 16,
#                     "visibilityMin": 16,
#                     "weatherCodeMax": 1100,
#                     "weatherCodeMin": 1100,
#                     "windDirectionAvg": 231,
#                     "windGustAvg": 7.7,
#                     "windGustMax": 11.5,
#                     "windGustMin": 4.6,
#                     "windSpeedAvg": 3.5,
#                     "windSpeedMax": 4.7,
#                     "windSpeedMin": 2.3
#                 }
#             },
#             {
#                 "time": "2025-06-15T05:00:00Z",
#                 "values": {
#                     "cloudBaseAvg": 0.9,
#                     "cloudBaseMax": 2.5,
#                     "cloudBaseMin": 0,
#                     "cloudCeilingAvg": 0.2,
#                     "cloudCeilingMax": 0.9,
#                     "cloudCeilingMin": 0,
#                     "cloudCoverAvg": 40,
#                     "cloudCoverMax": 100,
#                     "cloudCoverMin": 1,
#                     "dewPointAvg": 11.3,
#                     "dewPointMax": 12.1,
#                     "dewPointMin": 10.4,
#                     "evapotranspirationAvg": 0.125,
#                     "evapotranspirationMax": 0.185,
#                     "evapotranspirationMin": 0.088,
#                     "evapotranspirationSum": 2.995,
#                     "freezingRainIntensityAvg": 0,
#                     "freezingRainIntensityMax": 0,
#                     "freezingRainIntensityMin": 0,
#                     "humidityAvg": 71,
#                     "humidityMax": 87,
#                     "humidityMin": 51,
#                     "iceAccumulationAvg": 0,
#                     "iceAccumulationLweAvg": 0,
#                     "iceAccumulationLweMax": 0,
#                     "iceAccumulationLweMin": 0,
#                     "iceAccumulationLweSum": 0,
#                     "iceAccumulationMax": 0,
#                     "iceAccumulationMin": 0,
#                     "iceAccumulationSum": 0,
#                     "moonriseTime": "2025-06-15T23:26:27Z",
#                     "moonsetTime": "2025-06-15T07:34:14Z",
#                     "precipitationProbabilityAvg": 2.5,
#                     "precipitationProbabilityMax": 5,
#                     "precipitationProbabilityMin": 0,
#                     "pressureSeaLevelAvg": 1025.35,
#                     "pressureSeaLevelMax": 1029.07,
#                     "pressureSeaLevelMin": 1022.42,
#                     "pressureSurfaceLevelAvg": 1022.82,
#                     "pressureSurfaceLevelMax": 1026.52,
#                     "pressureSurfaceLevelMin": 1019.9,
#                     "rainAccumulationAvg": 0,
#                     "rainAccumulationMax": 0,
#                     "rainAccumulationMin": 0,
#                     "rainAccumulationSum": 0,
#                     "rainIntensityAvg": 0.03,
#                     "rainIntensityMax": 0.15,
#                     "rainIntensityMin": 0,
#                     "sleetIntensityAvg": 0,
#                     "sleetIntensityMax": 0,
#                     "sleetIntensityMin": 0,
#                     "snowAccumulationAvg": 0,
#                     "snowAccumulationLweAvg": 0,
#                     "snowAccumulationLweMax": 0,
#                     "snowAccumulationLweMin": 0,
#                     "snowAccumulationLweSum": 0,
#                     "snowAccumulationMax": 0,
#                     "snowAccumulationMin": 0,
#                     "snowAccumulationSum": 0,
#                     "snowIntensityAvg": 0,
#                     "snowIntensityMax": 0,
#                     "snowIntensityMin": 0,
#                     "sunriseTime": "2025-06-15T04:08:00Z",
#                     "sunsetTime": "2025-06-15T19:56:00Z",
#                     "temperatureApparentAvg": 16.9,
#                     "temperatureApparentMax": 20.8,
#                     "temperatureApparentMin": 13.8,
#                     "temperatureAvg": 16.9,
#                     "temperatureMax": 20.8,
#                     "temperatureMin": 13.8,
#                     "visibilityAvg": 16,
#                     "visibilityMax": 16,
#                     "visibilityMin": 16,
#                     "weatherCodeMax": 1000,
#                     "weatherCodeMin": 1000,
#                     "windDirectionAvg": 296,
#                     "windGustAvg": 6.1,
#                     "windGustMax": 9.1,
#                     "windGustMin": 3.6,
#                     "windSpeedAvg": 2.8,
#                     "windSpeedMax": 4,
#                     "windSpeedMin": 1.4
#                 }
#             }
#         ]
#     },
#     "location": {
#         "lat": 51.46773910522461,
#         "lon": -0.45878008008003235,
#         "name": "London Heathrow Airport, Northern Perimeter Road, London Borough of Hillingdon, London, Greater London, England, TW6 2RN, United Kingdom",
#         "type": "aerodrome"
#     }
# }

# %%
# Print the date of each of the 3 days you're getting a forecast for.
# Print the maximum temperature of each of the days.
# Print only the day with the highest maximum temperature.

forecast_days = weather_forecast['timelines']['daily'][:3]

for day in forecast_days:
    date = day['time']
    max_temp = day['values']['temperatureMax']
    print(f"Date: {date}, Max temperature: {max_temp} degrees Celsius.")
    print("-----")

hottest_day = max(forecast_days, key=lambda day: day['values']['temperatureMax'])

hottest_date = hottest_day['time']
hottest_temp = hottest_day['values']['temperatureMax']

print(f"The hottest day is {hottest_date} with a maximum temperature of {hottest_temp} degrees Celsius.")
# Out:
# Date: 2025-06-10T05:00:00Z, Max temperature: 23.4 degrees Celsius.
# -----
# Date: 2025-06-11T05:00:00Z, Max temperature: 23.1 degrees Celsius.
# -----
# Date: 2025-06-12T05:00:00Z, Max temperature: 24.1 degrees Celsius.
# -----
# The hottest day is 2025-06-12T05:00:00Z with a maximum temperature of 24.1 degrees Celsius.
